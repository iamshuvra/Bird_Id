# %% [markdown]
# <a href="https://colab.research.google.com/github/iamshuvra/Bird_Id/blob/main/Bird_Identification_Offshore_Wind_Turbine_Monitor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bird Identification - Offshore Wind Turbine Monitor
# Github repo: https://github.com/iamshuvra/Bird_Id.git [link text](https://)

# %%
https://github.com/iamshuvra/Bird_Id.git
